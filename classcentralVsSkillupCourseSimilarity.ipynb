# %% [markdown]
# ### Purpose: To find similar courses between classcentral and skillup by matching keywords of skillup with the courses title of classcentral, so that we can publish popular courses on classcentral from skillup to generate leads.

# %%
# Import modules
import pandas as pd
import re
import os
import numpy as np
import warnings
warnings.filterwarnings("ignore", "This pattern has match groups")

# %%
# List of files in the current directory
os.listdir()
# Out:
# ['classCentral_26Aug.xlsx',
#  '.ipynb_checkpoints',
#  'classcentralVsSkillupCourseSimilarity.ipynb',
#  'skillUp.xlsx']

# %%
# Read in class central data
df = pd.read_excel("classCentral_26Aug.xlsx")
df.head()
# Out:
#                                          courseTitle  \
# 0                                     Elements of AI
# 1                                   Machine Learning
# 2             Unlocking Information Security: Part Ⅰ
# 3  Introduction to Computer Science and Programmi...
# 4            CS50's Introduction to Computer Science
#
#                                           courseLink  \
# 0  https://www.classcentral.com/course/independen...
# 1  https://www.classcentral.com/course/machine-le...
# 2  https://www.classcentral.com/course/edx-unlock...
# 3  https://www.classcentral.com/course/edx-introd...
# 4  https://www.classcentral.com/course/edx-cs50-s...
#
#                                       courseProvider  \
# 0  University of Helsinki and Reaktor Education v...
# 1                   Stanford University via Coursera
# 2                        Tel Aviv University via edX
# 3      Massachusetts Institute of Technology via edX
# 4                         Harvard University via edX
#
#                                                  cat unitSold  \
# 0  Computer Science\n\n\n\n\nArtificial Intelligence    31.2k
# 1         Computer Science\n\n\n\n\nMachine Learning    62.3k
# 2            Computer Science\n\n\n\n\nCybersecurity     3.5k
# 3                                   Computer Science    16.4k
# 4                                   Computer Science    26.6k
#
#                  certificatePrice                 freeOrAudit       review
# 0           Certificate Available          Free Online Course  574 reviews
# 1      Paid Certificate Available  Free Online Course (Audit)  369 reviews
# 2  5 weeks long, 4-6 hours a week  Free Online Course (Audit)  151 reviews
# 3       $75 Certificate Available  Free Online Course (Audit)  126 reviews
# 4       $90 Certificate Available  Free Online Course (Audit)   96 reviews

# %%
# Extract subcategory and broadcategory from cat columns
df["subCat"] = df.cat.str.split("\n").str[-1]
df["broadCat"] = df.cat.str.split("\n").str[0]

# Extract digits from review
df["review"] = df.review.str.extract(r"(\d+,?)")

# %%
# Multiply by 1000 where unit sale contains "k", otherwise keep that as it is.
df["unitSold"] = np.where(df.unitSold.str.contains("k", na=False), 
        df.unitSold.str.replace("k", "").fillna(0).astype(float).multiply(1000).astype(int),
        df.unitSold).astype(int)

# Extract colaborating university from course provider column
df["colaboratingUniv"] = df.courseProvider.str.split("via").str[0].str.strip()


# Extract only course provider without colaborating university
df.courseProvider = df.courseProvider.str.split("via").str[-1].str.strip()

# Is the course is free, paid or auditable?
df["freeAuditOrPaid"] = np.where(df.freeOrAudit.str.contains("Audit"), "audit",
        np.where(df.freeOrAudit.str.contains("Free"), "free",
                np.where(df.freeOrAudit.str.contains("Paid"), "paid", df.freeOrAudit)))

# Is certificate free, paid or have some price?
df["certificatePrice"] = np.where(df.certificatePrice.str.contains("Paid"), "paid",
       np.where(df.certificatePrice.str.contains("\$"), df.certificatePrice,
                 np.where(df.certificatePrice.str.contains("Certificate Available"), "free", "na")))

# Split by certificate price, otherwise keep it as it is.
df["certificatePrice"] = np.where(df.certificatePrice.str.contains("\$"), 
         df.certificatePrice.str.split("Certificate Available").str[0], df.certificatePrice)

# Drop category column
df.drop("cat", axis=1, inplace=True)

# Sort by unit sale
df = df.sort_values("unitSold", ascending=False)

# %% [markdown]
# #### Read in skill up's data:

# %%
skill = pd.read_excel("skillUp.xlsx")
skill.head()
# Out:
#      date  courseId                                        courseTitle  \
# 0  18_Aug    277314   Animal Care and Pet First Aid - 5 Courses Bundle
# 1  18_Aug    273817           Dog Trainer - 8 Courses Complete Bundle
# 2  18_Aug    273884   Photography Bundle for Professional Photographer
# 3  18_Aug    277102                    BARF - Feed Your Dog A Raw Diet
# 4  18_Aug    277218  Reiki Diploma - Level 1 to Master Level Certif...
#
#                                              keyword  \
# 0                                        animal care
# 1  dog trainer|dog training|dog|dog walking|raw d...
# 2                    photography|wedding photography
# 3  dog trainer|dog training|dog|dog walking|raw d...
# 4                                              reiki
#
#                                             subTitle  \
# 0  Special Bundle Offer | Accredited by CPD | 13 ...
# 1  Special Bundle Offer | Accredited by CPD | 40 ...
# 2  Special Bundle Offer | Accredited by CPD | 45 ...
# 3  Accredited by CPD | 3 CPD Points | Video train...
# 4  Accredited by CPD | 4 CPD Points | Video train...
#
#                                           courseLink courseProvider  \
# 0  https://www.reed.co.uk/courses/animal-care-and...       Skill Up
# 1  https://www.reed.co.uk/courses/dog-trainer-8-c...       Skill Up
# 2  https://www.reed.co.uk/courses/photography-bun...       Skill Up
# 3  https://www.reed.co.uk/courses/barf-feed-your-...       Skill Up
# 4  https://www.reed.co.uk/courses/reiki-diploma-l...       Skill Up
#
#                            soldOrEnq  \
# 0   3 students purchased this course
# 1  11 students purchased this course
# 2   5 students purchased this course
# 3   5 students purchased this course
# 4  10 students purchased this course
#
#                                             category broadCategory1  ...  \
# 0     Animal care, Veterinary, Animal care, Dog care    Animal care  ...
# 1  Animal care, Dog training, Animal care, Dog tr...    Animal care  ...
# 2  Media and art, Photography, Recreational, Phot...  Media and art  ...
# 3  Animal care, Dog agility, Animal care, Dog wal...    Animal care  ...
# 4         Health & care, Alternative medicine, Reiki  Health & care  ...
#
#   cpdAccreditedBy othersAsCpd awrBodyName  awrBodyQualName courseLevel  \
# 0             NaN         NaN         NaN              NaN         NaN
# 1             NaN         NaN         NaN              NaN         NaN
# 2             NaN         NaN         NaN              NaN         NaN
# 3             NaN         NaN         NaN              NaN         NaN
# 4             NaN         NaN         NaN              NaN         NaN
#
#   savings newOfferPrice unitSold offerPrice  savingsPercent
# 0     NaN           NaN        3         39              96
# 1     NaN           NaN       11         49              94
# 2     NaN           NaN        5         49              94
# 3     NaN           NaN        5         10              95
# 4     NaN           NaN       10         10              95
#
# [5 rows x 29 columns]

# %%
# This function match keywords of skillup courses with the title of class central courses
def matchByKeyword(keyword):
    """Keyword: keyword in the skill up dataset."""
    
    # Search classcentral course title
    x = df[df["courseTitle"].str.contains(fr"\b({keyword})\b", case=False, regex=True)]
    
    # Insert keyword
    x.insert(loc=0, value=keyword, column="keyword")
    
    # Match keyword with the skill up keyword column
    y = skill[skill.keyword==keyword]
    
    # Concat if a keyword is found on both of the dataframes
    if x.shape[0]>0 and y.shape[0]>0:
        return pd.concat([y, x.head(10)])

# %%
# Call the function on array of keywords
matched = pd.concat(list(map(matchByKeyword, skill.keyword.unique()))).reset_index(drop=True)
matched.sample(10)
# Out:
#        date  courseId                                        courseTitle  \
# 277     NaN       NaN                                  Stress Management
# 146     NaN       NaN                      Character Setup and Animation
# 253  18_Aug  276951.0                American Sign Language (ASL) Course
# 188     NaN       NaN         Project Management: The Basics for Success
# 161     NaN       NaN  Course 3: Strategic Self-Marketing and Persona...
# 411     NaN       NaN               Front-End Web Development with React
# 282     NaN       NaN             Software Processes and Agile Practices
# 267     NaN       NaN                             Social Media Marketing
# 286     NaN       NaN                        Agile Meets Design Thinking
# 252     NaN       NaN                     Construct Stock Market Indices
#
#                          keyword  \
# 277                   cbt|stress
# 146                    animation
# 253   American Sign Language|asl
# 188        leadership|management
# 161                     branding
# 411  App Development|react|redux
# 282                        agile
# 267       Social Media Marketing
# 286                        agile
# 252                 Stock Market
#
#                                               subTitle  \
# 277                                                NaN
# 146                                                NaN
# 253  Accredited by CPD | 10 CPD Points | Exam inclu...
# 188                                                NaN
# 161                                                NaN
# 411                                                NaN
# 282                                                NaN
# 267                                                NaN
# 286                                                NaN
# 252                                                NaN
#
#                                             courseLink  \
# 277  https://www.classcentral.com/course/swayam-str...
# 146  https://www.classcentral.com/course/character-...
# 253  https://www.reed.co.uk/courses/american-sign-l...
# 188  https://www.classcentral.com/course/basicprojm...
# 161  https://www.classcentral.com/course/strategic-...
# 411  https://www.classcentral.com/course/front-end-...
# 282  https://www.classcentral.com/course/software-p...
# 267  https://www.classcentral.com/course/social-med...
# 286  https://www.classcentral.com/course/uva-darden...
# 252  https://www.classcentral.com/course/construct-...
#
#               courseProvider                       soldOrEnq  \
# 277                   Swayam                             NaN
# 146                 Coursera                             NaN
# 253                 Skill Up  Tutor is available to students
# 188                 Coursera                             NaN
# 161                 Coursera                             NaN
# 411                 Coursera                             NaN
# 282                 Coursera                             NaN
# 267  Coursera Specialization                             NaN
# 286                 Coursera                             NaN
# 252                 Coursera                             NaN
#
#                                               category broadCategory1  ...  \
# 277                                                NaN            NaN  ...
# 146                                                NaN            NaN  ...
# 253  Language, Sign language, Health & care, Care, ...       Language  ...
# 188                                                NaN            NaN  ...
# 161                                                NaN            NaN  ...
# 411                                                NaN            NaN  ...
# 282                                                NaN            NaN  ...
# 267                                                NaN            NaN  ...
# 286                                                NaN            NaN  ...
# 252                                                NaN            NaN  ...
#
#     unitSold offerPrice savingsPercent  certificatePrice  \
# 277      196        NaN            NaN              paid
# 146      122        NaN            NaN              paid
# 253        0       10.0           95.0               NaN
# 188    16800        NaN            NaN              paid
# 161      157        NaN            NaN              paid
# 411      621        NaN            NaN              paid
# 282     3200        NaN            NaN              paid
# 267      337        NaN            NaN              free
# 286     2100        NaN            NaN              paid
# 252       21        NaN            NaN              paid
#
#                     freeOrAudit review                  subCat  \
# 277          Free Online Course      0        Self Improvement
# 146  Free Online Course (Audit)      0                   Unity
# 253                         NaN    NaN                     NaN
# 188  Free Online Course (Audit)     25      Project Management
# 161  Free Online Course (Audit)      0                Branding
# 411  Free Online Course (Audit)      1                   React
# 282  Free Online Course (Audit)      8                   Agile
# 267                 Paid Course      1  Social Media Marketing
# 286  Free Online Course (Audit)      1                   Agile
# 252                 Paid Course      0                 Trading
#
#                  broadCat                                   colaboratingUniv  \
# 277  Personal Development  Indian Institute of Technology, Kharagpur and ...
# 146           Programming                                              Unity
# 253                   NaN                                                NaN
# 188              Business                   University of California, Irvine
# 161              Business                       State University of New York
# 411           Programming  The Hong Kong University of Science and Techno...
# 282           Programming                              University of Alberta
# 267              Business                            Northwestern University
# 286           Programming                             University of Virginia
# 252              Business                           Coursera Project Network
#
#      freeAuditOrPaid
# 277             free
# 146            audit
# 253              NaN
# 188            audit
# 161            audit
# 411            audit
# 282            audit
# 267             paid
# 286            audit
# 252             paid
#
# [10 rows x 36 columns]
